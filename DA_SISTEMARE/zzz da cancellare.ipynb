# %%
import os 
os.chdir('C:/Users/Carlo/')

# %%
# !python EasyMocap/apps/hopeitworks/ZZ_VERIFICATION2.py EasyMocap/data/output-keypoints3d/keypoints3d 3 12 6 EasyMocap/zzz_output.txt
# Out:
# Processato 000003.json: [0.0, 0.0, 0.0]
# Processato 000015.json: [0.1074296, 0.0421351, 0.0810693]
# Processato 000027.json: [0.0790279, 0.1476645, 0.044591]
# Processato 000039.json: [0.0909879, 0.1488836, 0.0426139]
# Processato 000051.json: [0.0886182, 0.1483732, 0.0464356]
# Processato 000063.json: [0.078036, 0.1431952, 0.0481797]
# Operazione completata. Salvati 6 valori in EasyMocap/zzz_output.txt

# %% [markdown]
# ![zzzz.png](attachment:206338c7-989a-4804-a8d6-440752738f82.png)
